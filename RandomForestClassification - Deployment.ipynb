# %%
import pickle

# %%
loaded_model=pickle.load(open("final_randomforest_classification.sav",'rb'))
Age=int(input("Please enter your Age"))
ES=int(input("Please enter your EstimatedSalary"))
Gender=input("Please enter your Gender").lower()
if (Gender=='Male'):
    gender=0
else:
    gender=1
result=loaded_model.predict([[Age,ES,gender]])   
if (result==0):
    print("They will not purchase")
else:
    print("They will purchase")
# Out:
# Please enter your Age 23
# Please enter your EstimatedSalary 34000
# Please enter your Gender male
# They will not purchase
# C:\Users\gayut\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
